# %% [markdown]
# <a href="https://colab.research.google.com/github/Kritisha57/Exploratory-Data-Analysis/blob/main/EDA_on_Bank_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# link for best visualization practices:
#
# https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#15.-Ordered-Bar-Chart

# %% [markdown]
# link for 100 tips & tricks in pandas:
#
# https://www.kaggle.com/code/shivan118/pandas-100-tricks

# %% [markdown]
# EDA and the following broad topics that will be covered in this training:
#
#     Data sourcing
#     Data cleaning
#     Univariate analysis
#     Bivariate and multivariate analysis

# %% [markdown]
# Exploratory data analysis uses data visualisation techniques to draw inferences and obtain insights from them. However, EDA is much more than plotting graphs or visualising data, it is more about understanding and studying the given data in detail. Visualisation of data into plots/graphs can be termed one of the tools in the EDA process.
#
#
#
# EDA also involves the preparation of data sets for analysis by removing irregularities in the data so that these irregularities do not affect further steps in the process of data analysis and machine learning model building.
#
#
#
# 1.   It is the most critical step in any DS activity
# 2.   If not done properly, it can jeopardize all the activities after that

# %% [markdown]
# the utility of EDA, which is as follows:
#
#     Maximise the insight in the data set
#
#     Detect outliers and anomalies
#
#     Test underlying assumptions

# %% [markdown]
# An important takeaway from this is that EDA should be the first step in any data science / machine learning activity. Based on the results of EDA, companies also make business decisions, which can have repercussions later. Hence, we observe the following:
#
# If not performed properly, EDA can hamper the further steps in the machine learning model building process.
#
# If done well, it may improve the efficacy of all we do in the next steps.

# %% [markdown]
# ## **Data Cleaning**
#
# Though data cleaning is often done in a somewhat haphazard manner, and it is difficult to define a ‘single structured process’, you will study data cleaning through the following steps:
#
#     Identifying the data types
#
#     Fixing the rows and columns
#
#     Imputing/removing missing values
#
#     Handling outliers
#
#     Standardising the values
#
#     Fixing invalid values
#
#     Filtering the data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
attribute_details=pd.read_excel('/content/drive/MyDrive/Bank dataset/Attribute details.xlsx')

# %%
attribute_details.head()
# Out:
#   Attributes details                                         Unnamed: 1
# 0        Customer id  This column is about the id of the customer co...
# 1                age   This column consists of the age of each customer
# 2             salary  This column represents monthly salary of the c...
# 3            balance  This column represents the cash balance in the...
# 4            marital   This column consists of the information about...

# %%
dtf=pd.read_csv('/content/drive/MyDrive/Bank dataset/bank_marketing_updated_v1.csv',header=None)

# %%
dtf.head()
# Out:
#                      0    1                             2        3   \
# 0     banking marketing  NaN                           NaN      NaN
# 1  customer id and age.  NaN  Customer salary and balance.      NaN
# 2            customerid  age                        salary  balance
# 3                     1   58                        100000     2143
# 4                     2   44                         60000       29
#
#                                                   4                     5   \
# 0                                                NaN                   NaN
# 1  Customer marital status and job with education...                   NaN
# 2                                            marital                jobedu
# 3                                            married   management,tertiary
# 4                                             single  technician,secondary
#
#                                            6        7   \
# ...

# %%
dtf=pd.read_csv('/content/drive/MyDrive/Bank dataset/bank_marketing_updated_v1.csv',skiprows=2)
dtf.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
dtf.drop('customerid',axis=1,inplace=True)
dtf.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# ...

# %%
#dividing job,edu into job and education
dtf['job']=dtf['jobedu'].apply(lambda x: x.split(',')[0])
dtf['edu']=dtf['jobedu'].apply(lambda x: x.split(',')[1])
dtf.head()
# Out:
#     age  salary  balance  marital                  jobedu targeted default  \
# 0  58.0  100000     2143  married     management,tertiary      yes      no
# 1  44.0   60000       29   single    technician,secondary      yes      no
# 2  33.0  120000        2  married  entrepreneur,secondary      yes      no
# 3  47.0   20000     1506  married     blue-collar,unknown       no      no
# 4  33.0       0        1   single         unknown,unknown       no      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
# 2     yes  yes  unknown    5  may, 2017   76 sec         1     -1         0
# 3     yes   no  unknown    5  may, 2017   92 sec         1     -1         0
# 4      no   no  unknown    5  may, 2017  198 sec         1     -1         0
#
#   poutcome response           job        edu
# ...

# %%
dtf.drop('jobedu',axis=1,inplace=True)

# %%
#dtf['month']=dtf.month.apply(lambda x: x.split(',')[0])

# %%
dtf[dtf.month.apply(lambda x: isinstance(x,float))==True]
# Out:
#         age  salary  balance   marital targeted default housing loan  \
# 189    31.0  100000        0    single       no      no     yes   no
# 769    39.0   20000      245   married      yes      no     yes   no
# 860    33.0   55000      165   married      yes      no      no   no
# 1267   36.0   50000      114   married      yes      no     yes  yes
# 1685   34.0   20000      457   married      yes      no     yes   no
# 1899   49.0   16000      164  divorced      yes      no     yes   no
# 2433   26.0   60000     3825   married      yes      no     yes   no
# 2612   38.0   50000      446    single       no      no     yes   no
# 2747   48.0  120000     2550   married       no      no     yes   no
# 3556   41.0   20000       59   married      yes      no     yes   no
# 3890   56.0   55000     4391   married       no      no     yes   no
# 5311   22.0   20000        0    single      yes      no     yes   no
# 6265   32.0   50000       13    single      yes      no     yes   no
# ...

# %%
dtf.isnull().sum()
# Out:
# age         20
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month       50
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response    30
# job          0
# edu          0
# dtype: int64

# %% [markdown]
# ## **Handling missing values**
# **Set values as missing values**: Identify values that indicate missing data, for example, treat blank strings "NA", "XX", "999", etc., as missing.
#
# **Adding is good, exaggerating is bad:** You should try to get information from reliable external sources as much as possible, but if you can’t, then it is better to retain missing values rather than exaggerating the existing rows/columns.
#
# **Delete rows and columns**: Rows can be deleted if the number of missing values is insignificant, as this would not impact the overall analysis results. Columns can be removed if the missing values are significant in number.
#
# **Fill partial missing values using business judgement**: Such values include missing time zones, century, etc. These values can be identified easily.

# %% [markdown]
# Types of missing values:
#
#     MCAR: It stands for Missing completely at random. The reason behind the missing value is not dependent on any other features.
#     MAR: It stands for Missing at random. The reason behind the missing value may be associated with some other features.
#     MNAR: It stands for Missing not at random. There is a specific reason behind the missing value.

# %%
# Dropping the null rows in age col
dtf=dtf[-(dtf['age'].isnull())].copy()
dtf.shape
# Out:
# (45191, 19)

# %%
# Handling missing values in month
dtf.month.isnull().sum()
# Out:
# 50

# %%
dtf['month'].value_counts()
# Out:
# may, 2017    13740
# jul, 2017     6885
# aug, 2017     6235
# jun, 2017     5333
# nov, 2017     3967
# apr, 2017     2930
# feb, 2017     2646
# jan, 2017     1402
# oct, 2017      737
# sep, 2017      576
# mar, 2017      476
# dec, 2017      214
# Name: month, dtype: int64

# %%
dtf['month'].fillna(dtf['month'].mode()[0],inplace=True)

# %%
dtf['month'].isnull().sum()
# Out:
# 0

# %%
# Handling pdays column
dtf['pdays'].value_counts()
# Only nan is not missing value. There are some indicators of missing vales too,
# like here, -1 is the missing value
# Out:
# -1      36939
#  182      167
#  92       146
#  91       126
#  183      126
#         ...
#  449        1
#  452        1
#  648        1
#  595        1
#  530        1
# Name: pdays, Length: 558, dtype: int64

# %%
# Our objective:
# We want missing values to be ignored in the calculations
# simply make it missing, replace -1 with NaN
dtf.loc[dtf['pdays']<0,'pdays']=np.nan

# statistical summaries do not consider null values in calculation.
# -1's were skewing our calculation as they were not being considered as null

# %%
dtf['pdays'].isnull().sum()
# Out:
# 36939

# %%
# Handling null values in the response column
dtf['response'].isnull().sum()
# Out:
# 30

# %%
100*(30/len(dtf))
# Out:
# 0.06638489964816004

# %%
# Since percentage of null values in response column is 0.06% only, we can drop the null values
dtf=dtf[-(dtf['response'].isnull())]

# %% [markdown]
# Remember, we cannot always impute the missing values in numerical columns with mean or median. If the data is continuous, imputing with mean or median will distort the data

# %% [markdown]
# ## **Handling Outliers**

# %% [markdown]
# the major approaches to the treatment of outliers can include:
#
#     Imputation
#
#     Deletion of outliers
#
#     Binning of values
#
#     Capping the outliers

# %%
# First step is finidng outliers then we go with handling them
# We'll go with numerical cols one by one

dtf['age'].describe()
#Since mean and median are almostb same, it appears to be normally distributed and not many outliers
# Out:
# count    45161.000000
# mean        40.935763
# std         10.618790
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
sns.boxplot(dtf['age'])
plt.show()
# The box plot shows above 70 people as outliers but they are normal values. People above 70 also participate in opening a term deposit

# %%
# Let's check the balance column
sns.boxplot(dtf['balance'])
plt.show()

# %%
dtf['balance'].describe()
# Out:
# count     45161.000000
# mean       1362.850690
# std        3045.939589
# min       -8019.000000
# 25%          72.000000
# 50%         448.000000
# 75%        1428.000000
# max      102127.000000
# Name: balance, dtype: float64

# %%
dtf.balance.value_counts()
# Out:
#  0        3511
#  1         194
#  2         156
#  4         139
#  3         134
#           ...
# -2827        1
# -1176        1
# -555         1
# -983         1
#  16353       1
# Name: balance, Length: 7166, dtype: int64

# %%
# We still need to analyze it further before we makea call
dtf['balance'].quantile([0.5, 0.7, 0.9 ,0.95, 0.99])
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.90     3576.0
# 0.95     5769.0
# 0.99    13173.4
# Name: balance, dtype: float64

# %%
# We have to see further whether the higher balances are anomalies or required.
dtf[dtf['balance']>15000].describe()
# These customers are important for bank so we cannot drop them. We will cap them
# Out:
#               age         salary        balance         day    campaign  \
# count  351.000000     351.000000     351.000000  351.000000  351.000000
# mean    45.341880   70008.547009   24295.780627   16.022792    2.749288
# std     12.114333   34378.272805   12128.560693    8.101819    3.036886
# min     23.000000       0.000000   15030.000000    1.000000    1.000000
# 25%     35.000000   50000.000000   17074.000000    9.000000    1.000000
# 50%     44.000000   60000.000000   20723.000000   18.000000    2.000000
# 75%     55.000000  100000.000000   26254.000000   21.000000    3.000000
# max     84.000000  120000.000000  102127.000000   31.000000   31.000000
#
#             pdays    previous
# count   62.000000  351.000000
# mean   188.516129    0.555556
# std    118.796388    1.784590
# min     31.000000    0.000000
# 25%     96.250000    0.000000
# 50%    167.500000    0.000000
# 75%    246.500000    0.000000
# max    589.000000   23.000000

# %% [markdown]
# For capping, instead of using mean we can use quantile/median/percentile
#
# An important aspect that has been covered is quantiles. Sometimes, it is beneficial if you look into the quantiles instead of the box plot, mean or median. Quantile may give you a fair idea about the outliers. If there is a huge difference between the maximum value and the 95th or 99th quantiles, then there are outliers in the data set.

# %%
dtf['salary'].describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
sns.boxplot(dtf['salary'])
plt.show()

# %% [markdown]
# In the salary column, the mean and median almost coincide, indicating an almost normal distribution. Also, no outliers can be seen in the box plot as well.

# %% [markdown]
# ## **Standardising values**

# %% [markdown]
# Scaling ensures that the values in a dataset have a common scale; this makes it easy to perform data analysis. Let's take a data set that contains the grades of students studying in different universities. Some of the universities assign grades on a scale of 4, whereas the others assign grades on a scale of 10. Hence, you cannot assume that a GPA of 3 on a scale of 4 is equal to a GPA of 3 on a scale of 10, even though they are the same quantitatively. Thus, for the purpose of analysis, these values need to be brought to a common scale, such as the percentage scale.
#
#     Standardise units: Ensure all observations under one variable are expressed in a common and consistent unit, e.g., convert lbs to kg, miles/hr to km/hr, etc.
#
#     Scale values if required: Make sure all the observations under one variable have a common scale.
#
#     Standardise precision for a better presentation of data, e.g., change 4.5312341 kg to 4.53 kg.
#
#     Remove extra characters such as common prefixes/suffixes, leading/trailing/multiple spaces, etc. These are irrelevant to the analysis.
#
#     Standardise case: String variables may take various casing styles, e.g., FULLCAPS, lowercase, Title Case, Sentence case, etc.
#
#     Standardise format: It is important to standardise the format of other elements such as date, name, etc. For example, change 23/10/16 to 2016/10/23, “Modi, Narendra” to “Narendra Modi", etc.

# %%
#Analyzing Duration variable
dtf['duration'].value_counts()
# Out:
# 1.5 min                 138
# 1.68333333333333 min    129
# 2.06666666666667 min    129
# 1.73333333333333 min    127
# 2.03333333333333 min    127
#                        ...
# 1500 sec                  1
# 22.1666666666667 min      1
# 868 sec                   1
# 1269 sec                  1
# 16.2833333333333 min      1
# Name: duration, Length: 2646, dtype: int64

# %%
dtf['duration']=dtf['duration'].apply(lambda x: round(float(x.split(' ')[0]),2) if x.split(' ')[1]=='min' else round(float(x.split(' ')[0]),2)/60)

# %%
dtf.duration.describe()
# Out:
# count    45161.000000
# mean         4.302776
# std          4.293134
# min          0.000000
# 25%          1.720000
# 50%          3.000000
# 75%          5.316667
# max         81.970000
# Name: duration, dtype: float64

# %%
sns.boxplot(dtf['duration'])
plt.show()

# %%
dtf[dtf['duration']>60]
# Out:
#         age  salary  balance  marital targeted default housing loan  \
# 9947   59.0  100000     1321  married      yes      no      no   no
# 24148  59.0   60000     6573  married      yes      no     yes   no
# 44602  45.0   70000      955   single      yes      no      no   no
#
#          contact  day      month   duration  campaign  pdays  previous  \
# 9947     unknown    9  jun, 2017  64.683333         3    NaN         0
# 24148  telephone   10  nov, 2017  81.970000         1    NaN         0
# 44602    unknown   27  aug, 2017  63.080000         1    NaN         0
#
#       poutcome response         job        edu
# 9947   unknown      yes  management  secondary
# 24148  unknown       no  technician   tertiary
# 44602  unknown       no    services  secondary

# %%
# Since these 3 customers took more than 60mins on call and still didn't show positive response, also their balance is very low
# They are less likely to go for a term deposit. Hence we can drop them

dtf=dtf[-(dtf['duration']>60)]

# %% [markdown]
# ## **Fixing invalid values**

# %% [markdown]
#     Encode unicode properly: In case the data is being read as junk characters, try to change the encoding, for example, use CP1252 instead of UTF-8.
#
#     Convert incorrect data types: Change the incorrect data types to the correct data types for ease of analysis. For example, if numeric values are stored as strings, then it would not be possible to calculate metrics such as mean, median, etc. Some of the common data type corrections include changing a string to a number ("12,300" to “12300”), a string to a date ("2013-Aug" to “2013/08”), a number to a string (“PIN Code 110001” to "110001"), etc.
#
#     Correct the values that lie beyond the range: If some values lie beyond the logical range, for example, temperature less than -273° C (0° K), then you would need to correct those values as required. A close look at the data set would help you determine whether there is scope for correction or the value needs to be removed.
#
#     Correct the values not belonging in the list: Remove the values that do not belong to a list. For example, in a data set of blood groups of individuals, strings ‘E’ or ‘F’ are invalid values and can be removed.
#
#     Fix incorrect structure: Values that don’t follow a defined structure can be removed from a data set. For example, in a data set containing the pin codes of Indian cities, a pin code of 12 digits would be an invalid value and would need to be removed. Similarly, a phone number of 12 digits would be an invalid value.
#
#     Validate internal rules: Internal rules, if present, should be correct and consistent. For example, the date of a product’s delivery should definitely come after the date of purchase.

# %% [markdown]
# Although you have a largely accurate dataset by now, you may not need all of it for your analysis. It is important for you to understand what you need in order to draw insights from the data, and then choose relevant parts of the dataset for your analysis. Thus, you need to filter the data in order to get what you need for your analysis.

# %% [markdown]
# ## **Univariate Analysis**

# %% [markdown]
# Understanding one variable at a time
#
# univariate analysis, which broadly is of the following four types:
#
#     Categorical unordered univariate analysis
#     Categorical ordered univariate analysis
#     Statistics on the numerical variable
#     Numerical variable univariate analysis

# %% [markdown]
# The concept of univariate analysis is divided into **ordered and unordered category** of variables. In this segment, you will learn how to conduct univariate analysis on categorical unordered variables.
#
#
#
# Unordered data is the type of data that does not have any measurable terms (measurable terms can be like high-low, more-less, fail-pass, etc.) Example:
#
# * The type of loan taken by an individual (home loan, personal loan, auto loan, etc.) does not have any ordered notion. They are just different types of loans.
#
#
# * Departments of an organisation — Sales, Marketing, HR — are different departments in an organization, with no measurable attribute attached to any term.
#
# Unordered variables also called Nominal variables.

# %%
dtf.dtypes
# Out:
# age         float64
# salary        int64
# balance       int64
# marital      object
# targeted     object
# default      object
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration    float64
# campaign      int64
# pdays       float64
# previous      int64
# poutcome     object
# response     object
# job          object
# edu          object
# dtype: object

# %%
dtf['marital'].value_counts(normalize=True).plot.barh()
# Out:
# <Axes: >

# %%
dtf['job'].value_counts(normalize=True).plot.barh()
# Out:
# <Axes: >

# %% [markdown]
# **Categorical Ordered Univariate Analysis**
#
# Ordered variables are those variables that follow a natural rank of order. Some examples of categorical ordered variables from the Bank Marketing dataset are:
#
# * Age group:  <30, 30-40, 40-50 and so on
#
# * Month: Jan, Feb, Mar, etc.
#
# * Education: primary, secondary and so on

# %%
# Education variable is a categorical ordered variable

dtf['edu'].value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='edu'>

# %%
# poutcome variable
dtf[-(dtf['poutcome']=='unknown')].poutcome.value_counts(normalize=True).plot.bar()
# Out:
# <Axes: >

# %%
dtf['response'].value_counts(normalize=True).plot.pie()
# Out:
# <Axes: ylabel='response'>

# %% [markdown]
# **Statistics on numerical features**
#
# Numeric variables can be continuous like height, temperature, weight, etc. Numerical variables can also be discrete like the number of items bought by a customer in a store, the number of people in a city, the number of 'heads' you get when flipping three coins.

# %% [markdown]
# For numeric variables we can create summary statistics to analyse them which is traditionally considered as univariate analysis.
#
# When to use mean/median/mode?
#
# * For categorical variable, use mode
# * For numeric variable, if there is an outlier, far from the major chunk of data, obviously taking the mean would include the outlier as well and would not give a correct picture of underlying trend of the data. Hence, if there are outliers, median is preferred since it is not affected by outliers.
#
# * Also, median gives a value that can generalize a reasonably large chunk of population
#
# **When you can take the data and redistribute it, mean is used. When we want a representative of the dataset, or representative of a major portion of the data, we use median**

# %% [markdown]
# Both standard deviation and interquartile difference are used to represent the spread of the data.
#
#
#
# The interquartile difference is a much better metric than standard deviation if there are outliers in the data because the standard deviation will be influenced by outliers, while the interquartile difference will simply ignore them.

# %% [markdown]
# ## **Bivariate Analysis**
#
# Bivariate analysis enables us to look at patterns at the data

# %% [markdown]
# **Numeric-Numeric analysis**
#
# Plot types:
# * Correlation matrix
# * scatter plot
# * Pair plot
#
#
# In the correlation matrix, there are multiple values written in boxes that show the relation between the variables. These values are called 'Pearson coefficients'. SOme points about correlation coefficients:
# * The correlation matrix quantifies only the linear dependence between the variables; it does not capture the nonlinear relations between them
# * The correlation coefficient is sensitive to outliers.

# %% [markdown]
# However, the correlation matrix has its own limitations where you cannot see the exact distribution of a variable with another numeric variable. To solve this problem, we use pair plots. Pair plots are scatter plots of all numeric variables in a data set. It shows the exact variation of one variable with respect to the others. You can observe how one variable is varying with respect to another in the image below.

# %%
plt.scatter(dtf['salary'],dtf['balance'])
plt.show()

# %%
dtf.plot.scatter(x='age',y='balance')
plt.show()

# %%
sns.pairplot(data=dtf,vars=['salary','balance','age'])
plt.show()

# %%
# Quantifying using correlation values

dtf[['age','salary','balance']].corr()
# Out:
#               age    salary   balance
# age      1.000000  0.024458  0.097657
# salary   0.024458  1.000000  0.055490
# balance  0.097657  0.055490  1.000000

# %%
sns.heatmap(dtf[['age','balance','salary']].corr(),annot=True,cmap='Reds')
# Out:
# <Axes: >

# %% [markdown]
# A high correlation coefficient does not imply that there will be a correlation with another numeric variable every time because there can be no causation between them. There may be cases where you will see a high correlation coefficient between two variables but there is no relation between them

# %% [markdown]
# **Correlation v/s Causation**
# Correlation does not imply causation, i.e, one variable is the cause of another or affects another variable in any way. Just by observing a high correlation coeff we can't conclude whether there is a causation or not but we can hypothesise like "maybe increasing var_x will increase var_y "

# %% [markdown]
# **Numeric-Categorical Analysis**

# %% [markdown]
# Our response feataure is categorical. We can compare reponse feature with numeric features and analyze them.

# %%
dtf.groupby('response')['salary'].mean()
# Out:
# response
# no     56769.097658
# yes    58772.710068
# Name: salary, dtype: float64

# %%
dtf.groupby('response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
sns.boxplot(data=dtf,x='response',y='salary')
plt.show()

# %%
# Response v/s balance
# We know that balance is highly skewed i.e, has a very high value
sns.boxplot(data=dtf,x='response',y='balance')
plt.show()

# %% [markdown]
# We observed that after the balance versus response graph is plotted, it does not make any sense at first glance. Sometimes only a boxplot is not sufficient to draw insights, because of a high concentration of data and or because of higher values in the data set, for example, the balance variable.

# %%
#Since nothing is much clear from the box plot, we'll go with groupby

dtf.groupby('response')['balance'].mean()
# Out:
# response
# no     1304.168907
# yes    1804.772899
# Name: balance, dtype: float64

# %%
dtf.groupby('response')['balance'].median()
# Out:
# response
# no     417.0
# yes    733.0
# Name: balance, dtype: float64

# %%
# 75th percentile
def p75(x):
  return np.quantile(x,0.75)

# %%
dtf.groupby('response')['balance'].aggregate(['mean','median',p75])
# Out:
#                  mean  median      p75
# response
# no        1304.168907   417.0  1345.00
# yes       1804.772899   733.0  2159.25

# %%
dtf.groupby('response')['balance'].aggregate(['mean','median',p75]).plot.bar()
# Out:
# <Axes: xlabel='response'>

# %%
# Question- Which of the education levels shows the highest mean and the lowest median value for salary
sns.boxplot(data=dtf,x='edu',y='salary')
plt.show()

# %%
dtf.groupby('edu')['salary'].aggregate(['mean','median'])
# Out:
#                    mean    median
# edu
# primary    34232.343910   20000.0
# secondary  49728.406247   55000.0
# tertiary   82881.972149  100000.0
# unknown    46529.633621   50000.0

# %%
# Question- What inferences can you draw by taking a look at the mean values of salary in each job category?
dtf.groupby('job')['salary'].mean()
# Out:
# job
# admin.            50000.0
# blue-collar       20000.0
# entrepreneur     120000.0
# housemaid         16000.0
# management       100000.0
# retired           55000.0
# self-employed     60000.0
# services          70000.0
# student            4000.0
# technician        60000.0
# unemployed         8000.0
# unknown               0.0
# Name: salary, dtype: float64

# %%
# We'll also see the response of each job category
dtf.groupby('job')['response'].value_counts()
# Out:
# job            response
# admin.         no          4535
#                yes          630
# blue-collar    no          9014
#                yes          708
# entrepreneur   no          1361
#                yes          123
# housemaid      no          1130
#                yes          108
# management     no          8150
#                yes         1300
# retired        no          1747
#                yes          515
# self-employed  no          1388
#                yes          186
# services       no          3778
#                yes          369
# student        no           669
#                yes          269
# technician     no          6748
#                yes          840
# unemployed     no          1100
#                yes          202
# unknown        no           254
#                yes           34
# Name: response, dtype: int64

# %% [markdown]
# **Categorical-categorical analysis**
#
# Here, you will learn how to analyse categorical variables using graphs and charts, and derive maximum insights from them.

# %%
dtf['response_flag']=np.where(dtf['response']=='yes',1,0)

# %%
dtf.response_flag.value_counts()
# Out:
# 0    39874
# 1     5284
# Name: response_flag, dtype: int64

# %%
# Response rate
dtf.response_flag.value_counts(normalize=True)
# Out:
# 0    0.882989
# 1    0.117011
# Name: response_flag, dtype: float64

# %%
dtf.response_flag.mean()
# Out:
# 0.11701138225785021

# %%
# Education v/s response rate
dtf.groupby('edu')['response_flag'].mean().plot.bar()
# Out:
# <Axes: xlabel='edu'>

# %%
# Marital v's response rate
dtf.groupby('marital')['response_flag'].mean().plot.bar()
# Out:
# <Axes: xlabel='marital'>

# %%
dtf.groupby('loan')['response_flag'].mean().plot.barh()
# Out:
# <Axes: ylabel='loan'>

# %% [markdown]
# People who've already taken a loan are less likely to open a fixed deposit.

# %%
# Age v/s response rate
dtf['age'].unique()

# %%
def age_func(val):
  if type(val)==str:
    return float(val)
dtf['age']=dtf['age'].apply(age_func)

# %%
dtf['age'].head()

# %%
dtf=dtf[-(dtf['age'].isnull())]

# %%
dtf.head()

# %%
dtf.reset_index()['age'].mean()

# %%
sns.boxplot(data=dtf,x='response',y='age')
plt.show()

# %%
# ?pd.cut

# %%
pd.cut(dtf.age,[0,30,40,50,60,9999],labels=['<30','30-4-','40-50','50-60','60+'])
# Out:
# 0        50-60
# 1        40-50
# 2        30-4-
# 3        40-50
# 4        30-4-
#          ...
# 45206    50-60
# 45207      60+
# 45208      60+
# 45209    50-60
# 45210    30-4-
# Name: age, Length: 45158, dtype: category
# Categories (5, object): ['<30' < '30-4-' < '40-50' < '50-60' < '60+']

# %%
dtf.age.head()
# Out:
# 0    58.0
# 1    44.0
# 2    33.0
# 3    47.0
# 4    33.0
# Name: age, dtype: float64

# %%
dtf['age_group']=pd.cut(dtf.age,[0,30,40,50,60,9999],labels=['<30','30-40','40-50','50-60','60+'])

# %%
dtf.age_group.value_counts()
# Out:
# 30-40    17662
# 40-50    11230
# 50-60     8055
# <30       7025
# 60+       1186
# Name: age_group, dtype: int64

# %%
dtf.age_group.value_counts(normalize=True)
# Out:
# 30-40    0.391116
# 40-50    0.248682
# 50-60    0.178374
# <30      0.155565
# 60+      0.026263
# Name: age_group, dtype: float64

# %%
plt.figure(figsize=[10,4])
plt.subplot(1,2,1)
dtf.age_group.value_counts(normalize=True).plot.bar()
plt.subplot(1,2,2)
dtf.groupby('age_group')['response_flag'].mean().plot.bar()
plt.show()

# %% [markdown]
# So, age group analysis showed that people in the age group of 60+ or <30 are more likely to respond positively. It may be true for older people, since they want to invest through more secure investment methods such as term deposits to have a secure old age.

# %% [markdown]
# ## **Multivariate Analysis**
#
# So far, you have learnt how two variables can be visualised based on their type, for example, numerical, categorical, etc. Now, let’s analyse two variables simultaneously. One of the key features of multivariate analysis is that it gives you a very precise idea about the various elements, since you are now combining multiple variables to visualise the data set.

# %%
res=pd.pivot_table(data=dtf,index='edu',columns='marital',values='response_flag')

# %%
res
# Out:
# marital    divorced   married    single
# edu
# primary    0.138852  0.075601  0.106808
# secondary  0.103559  0.094584  0.129291
# tertiary   0.137415  0.129854  0.183737
# unknown    0.142012  0.122519  0.162879

# %%
sns.heatmap(res,annot=True)
# Out:
# <Axes: xlabel='marital', ylabel='edu'>

# %%
sns.heatmap(res,annot=True,cmap="RdYlGn")
# Out:
# <Axes: xlabel='marital', ylabel='edu'>

# %% [markdown]
# A three-variable analysis between education, marital status and response:-
#
#  You can see that people who are married and who have completed just their primary education are least likely to give a positive response on term deposits. This can be explained by the fact that people educated only up to the primary level are not aware of the benefits of term investments.  Also, married individuals need money to fulfil their daily needs, and they require cash-on-hand to buy the daily essentials; hence, they won't prefer investing in term deposits.

# %%
res1=pd.pivot_table(data=dtf,index='marital',columns='job',values='response_flag')

# %%
sns.heatmap(res1,annot=True,cmap='RdYlGn',center=0.117)
# Out:
# <Axes: xlabel='job', ylabel='marital'>

# %%
dtf[dtf.pdays>0].response_flag.mean()
# Out:
# 0.2307785593014795

# %%
# It is advised to take center around the mean of the column rathar than a random value
res=pd.pivot_table(data=dtf,index='edu',columns='poutcome',values='response_flag')
sns.heatmap(res,annot=True,cmap='RdYlGn',center=0.23)
plt.show()

# %% [markdown]
# the combinations of married with blue-collar, entrepreneur and housemaid are least likely to go for term deposits. The highest rate of positive response came from students with single marital status. The bank should, therefore, consider these aspects before taking any decision.
